# %%
def pcg(s, _=None):
    t = (s * 313901031 + 19238194041) & 0xffffffffffffffff    
    return t, t >> ((t>>(47+((t >> 61) & 0x7))) & 0xf) & 0xfffffffff 

pcg(*pcg(*pcg(*pcg(42))))
# Out:
# (13912395187885345210, 48952518811)
